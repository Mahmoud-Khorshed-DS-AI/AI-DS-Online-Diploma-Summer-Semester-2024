# %% [markdown]
# # Session 7

# %% [markdown]
# ## Pandas
#
# Often data is stored in comma separated values (CSV) files.
# For the remainder of this lab, we'll be working with automobile data, where we've extracted relevant parts below. Note that CSV files can be output by any spreadsheet software, and are plain text, hence are a great way to share data. Pandas can also read excel format.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To use Pandas, we first need to import the `pandas` package:

# %%
import pandas as pd

# %% [markdown]
# ### The Pandas Series Object
#
# A Pandas ``Series`` is a one-dimensional array of indexed data. It is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.). The axis labels are collectively called index. Pandas Series is nothing but a column in an excel sheet.
# Labels need not be unique but must be a hashable type. The object supports both integer and label-based indexing and provides a host of methods for performing operations involving the index.
#
# ![image.png](data:image/png;base64,...)
#
# Reference: https://www.geeksforgeeks.org/python-pandas-series/

# %% [markdown]
# #### 1- Create from list
#
# Pandas series can be extracted from a dataframe, or they can be created from a list or array as follows:

# %%
x = [1,2,3]

pd.Series(x)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([1,2,3.5,'4',True])
# Out:
# 0       1
# 1       2
# 2     3.5
# 3       4
# 4    True
# dtype: object

# %%
data = pd.Series(
                 index=[1,2,5,6],
                 data=[0.25, 0.5, 0.75, 1.0]
                 )
data
# Out:
# 1    0.25
# 2    0.50
# 5    0.75
# 6    1.00
# dtype: float64

# %% [markdown]
# As we see in the output, the ``Series`` wraps both a sequence of values and a sequence of indices, which we can access with the ``values`` and ``index`` attributes.
# The ``values`` are simply a familiar NumPy array:

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %% [markdown]
# The ``index`` is an array-like object of type ``pd.Index``, which we'll discuss in more detail momentarily.

# %%
data.index
# Out:
# Int64Index([1, 2, 5, 6], dtype='int64')

# %% [markdown]
# Like with a NumPy array, data can be accessed by the associated index via the familiar Python square-bracket notation:

# %%
data
# Out:
# 1    0.25
# 2    0.50
# 5    0.75
# 6    1.00
# dtype: float64

# %%
data[1]
# Out:
# 0.25

# %%
data[5]  # from human eyes
# Out:
# 0.75

# %%
data
# Out:
# 1    0.25
# 2    0.50
# 5    0.75
# 6    1.00
# dtype: float64

# %%
data[2:4] # from computer eyes
# Out:
# 5    0.75
# 6    1.00
# dtype: float64

# %%
data
# Out:
# 1    0.25
# 2    0.50
# 5    0.75
# 6    1.00
# dtype: float64

# %%
data[1:7]
# Out:
# 2    0.50
# 5    0.75
# 6    1.00
# dtype: float64

# %%
data[7]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 7
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 data[7]
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 7

# %%
data[7:8]
# Out:
# Series([], dtype: float64)

# %%
data
# Out:
# 1    0.25
# 2    0.50
# 5    0.75
# 6    1.00
# dtype: float64

# %%
data[1:4]
# Out:
# 2    0.50
# 5    0.75
# 6    1.00
# dtype: float64

# %%
data
# Out:
# 1    0.25
# 2    0.50
# 5    0.75
# 6    1.00
# dtype: float64

# %%
data[5:7]
# Out:
# Series([], dtype: float64)

# %%
data[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 data[3]
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 3

# %%
data[6] # human eyes
# Out:
# 1.0

# %%
data
# Out:
# 1    0.25
# 2    0.50
# 5    0.75
# 6    1.00
# dtype: float64

# %%
data[1]
# Out:
# 0.25

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
data.values[1]
# Out:
# 0.5

# %%
data[5]
# Out:
# 0.75

# %%
data[0:2]
# Out:
# 1    0.25
# 2    0.50
# dtype: float64

# %% [markdown]
# #### Create from dictionary
#
# In this way, you can think of a Pandas ``Series`` a bit like a specialization of a Python dictionary.
# A dictionary is a structure that maps arbitrary keys to a set of arbitrary values, and a ``Series`` is a structure which maps typed keys to a set of typed values.
# This typing is important: just as the type-specific compiled code behind a NumPy array makes it more efficient than a Python list for certain operations, the type information of a Pandas ``Series`` makes it much more efficient than Python dictionaries for certain operations.
#
# The ``Series``-as-dictionary analogy can be made even more clear by constructing a ``Series`` object directly from a Python dictionary:

# %%
population_dict = {'California': 38332521,  #Key   Value
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}


population_ser = pd.Series(population_dict)
population_ser
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
population_ser.values
# Out:
# array([38332521, 26448193, 19651127, 19552860, 12882135], dtype=int64)

# %%
population_ser.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %% [markdown]
# By default, a ``Series`` will be created where the index is drawn from the sorted keys.
# From here, typical dictionary-style item access can be performed:

# %%
population_ser
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
population_ser['California']
# Out:
# 38332521

# %% [markdown]
# Unlike a dictionary, though, the ``Series`` also supports array-style operations such as slicing:

# %%
population_ser
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
population_ser[1:3] # 3 exclusive
# Out:
# Texas       26448193
# New York    19651127
# dtype: int64

# %%
population_ser[0:4]
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# dtype: int64

# %%
population_ser
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
population_ser['California':'Illinois']   # last is inclusive when string
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %% [markdown]
# **Task**
#
#
# 1- create comprehnsion dictionary 10 numbers (Key : value) number : square(number)
#
# 2- create series using dictionary
#
# 3- print range 5 to 9  (9 inclusive)
#
# 4- print index = 3
#
# 5- print index = 11

# %%
dictt = {x:x**2 for x in range (0,10)}
dictt
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
dict_s = pd.Series(dictt)
dict_s
# Out:
# 0     0
# 1     1
# 2     4
# 3     9
# 4    16
# 5    25
# 6    36
# 7    49
# 8    64
# 9    81
# dtype: int64

# %%
dict_s[5:10]
# Out:
# 5    25
# 6    36
# 7    49
# 8    64
# 9    81
# dtype: int64

# %%
dict_s[3]
# Out:
# 9

# %%
dict_s[11]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 11
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 dict_s[11]
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 11

# %% [markdown]
# ### Pandas Data Frame
# Pandas DataFrame is two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns. Pandas DataFrame consists of three principal components, the data, rows, and columns.
#
# ![image.png](data:image/png;base64,...)
#
# Reference: https://www.geeksforgeeks.org/python-pandas-dataframe/

# %% [markdown]
# #### From a single Series object
#
# A ``DataFrame`` is a collection of ``Series`` objects, and a single-column ``DataFrame`` can be constructed from a single ``Series``:

# %%
population_dict = {'California': 38332521,
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}

population = pd.Series(population_dict)

pd.DataFrame(population, columns=['population'])
# Out:
#             population
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135

# %%
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
stu_d = {'mah':5,
         'ahm':2.5,
         'kar':4}

stu_s  = pd.Series(
                    stu_d
                   )

stu_df = pd.DataFrame(
                      stu_s,
                      columns=['GPA']
                      )

stu_df
# Out:
#      GPA
# mah  5.0
# ahm  2.5
# kar  4.0

# %%
stu_df.reset_index()  #inplace=True
# stu_df
# Out:
#   index  GPA
# 0   mah  5.0
# 1   ahm  2.5
# 2   kar  4.0

# %%
stu_df
# Out:
#      GPA
# mah  5.0
# ahm  2.5
# kar  4.0

# %%
stu_df.reset_index(inplace=True)

# %%
stu_df
# Out:
#   index  GPA
# 0   mah  5.0
# 1   ahm  2.5
# 2   kar  4.0

# %%
stu_df.rename(columns={'index':'Names'},
              inplace=True
              )

# %%
stu_df
# Out:
#   Names  GPA
# 0   mah  5.0
# 1   ahm  2.5
# 2   kar  4.0

# %% [markdown]
# #### From a list of dictionaries
#
# Any list of dictionaries can be made into a ``DataFrame``.
#
# Key >>  column name
#
# Value >> Row value

# %%
row1 = {'Name': 'Mahmoud' , 'Salary': 1500 ,'Age': 28 }
row2 = {'Name': 'Ahmed'   , 'Salary': 985 , 'Age': 35 }

# %%
df1 = pd.DataFrame( [row1,row2] )
df1
# Out:
#       Name  Salary  Age
# 0  Mahmoud    1500   28
# 1    Ahmed     985   35

# %% [markdown]
# task
#
# Create dataframe
#
# 3 rows
#
# 4 columns
#
# Name  Salary  City job

# %%
df1
# Out:
#       Name  Salary  Age
# 0  Mahmoud    1500   28
# 1    Ahmed     985   35

# %%
df1.shape # #rows  , Cols
# Out:
# (2, 3)

# %%
df1.dtypes
# Out:
# Name      object
# Salary     int64
# Age        int64
# dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      object
#  1   Salary  2 non-null      int64
#  2   Age     2 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 180.0+ bytes

# %%
data = pd.Series(['Karim','Aballah','Alaa','Haythem'], index=[1, 3, 5,6])
data
# Out:
# 1      Karim
# 3    Aballah
# 5       Alaa
# 6    Haythem
# dtype: object

# %%
# explicit index when indexing
data[1]  # human eye
# Out:
# 'Karim'

# %%
# implicit index when slicing
data[1:3]  # computer
# Out:
# 3    Aballah
# 5       Alaa
# dtype: object

# %% [markdown]
# ### Data Selection in DataFrame
#
# Recall that a ``DataFrame`` acts in many ways like a two-dimensional or structured array, and in other ways like a dictionary of ``Series`` structures sharing the same index.
# These analogies can be helpful to keep in mind as we explore data selection within this structure.

# %% [markdown]
# #### DataFrame as a dictionary
#
# The first analogy we will consider is the ``DataFrame`` as a dictionary of related ``Series`` objects.
# Let's return to our example of areas and populations of states:

# %%
row_1 = {'City': 'Alex', 'Pop': 655500 , 'True' : 2500}    # Column name and value
row_2 = {'City': 'Mecca', 'Pop': 254400 , 'True' : 9820}    # Column name and value


data = pd.DataFrame([row_1, row_2])
data
# Out:
#     City     Pop  True
# 0   Alex  655500  2500
# 1  Mecca  254400  9820

# %% [markdown]
# The individual ``Series`` that make up the columns of the ``DataFrame`` can be accessed via dictionary-style indexing of the column name:

# %%
data['City']
# Out:
# 0     Alex
# 1    Mecca
# Name: City, dtype: object

# %% [markdown]
# Equivalently, we can use attribute-style access with column names that are strings:

# %%
data.City
# Out:
# 0     Alex
# 1    Mecca
# Name: City, dtype: object

# %%
data['True']
# Out:
# 0    2500
# 1    9820
# Name: True, dtype: int64

# %%
data.True  # reserved word
# Out:
#   Cell In[69], line 1
#     data.True  # reserved word
#          ^
# SyntaxError: invalid syntax

# %%
data.Pop
# Out:
# 0    655500
# 1    254400
# Name: Pop, dtype: int64

# %% [markdown]
# This attribute-style column access actually accesses the exact same object as the dictionary-style access:

# %%
data.Pop is data['Pop']
# Out:
# True

# %% [markdown]
# Though this is a useful shorthand, keep in mind that it does not work for all cases!
# For example, if the column names are not strings, or if the column names conflict with methods of the ``DataFrame``, this attribute-style access is not possible.
# For example, the ``DataFrame`` has a ``pop()`` method, so ``data.pop`` will point to this rather than the ``"pop"`` column:

# %%
data
# Out:
#     City     Pop  True
# 0   Alex  655500  2500
# 1  Mecca  254400  9820

# %%
data
# Out:
#     City     Pop  True
# 0   Alex  655500  2500
# 1  Mecca  254400  9820

# %%
data.rename(columns = {'True':'Area'},inplace=True)

# %%
data
# Out:
#     City     Pop  Area
# 0   Alex  655500  2500
# 1  Mecca  254400  9820

# %% [markdown]
# Feature engineering

# %%
data['Density'] =  data['Pop'] / data['Area']
data
# Out:
#     City     Pop  Area     Density
# 0   Alex  655500  2500  262.200000
# 1  Mecca  254400  9820   25.906314

# %%
data['zip'] = [3,5]
data
# Out:
#     City     Pop  Area     Density  zip
# 0   Alex  655500  2500  262.200000    3
# 1  Mecca  254400  9820   25.906314    5

# %% [markdown]
# This shows a preview of the straightforward syntax of element-by-element arithmetic between ``Series`` objects; we'll dig into this further in [Operating on Data in Pandas](03.03-Operations-in-Pandas.ipynb).

# %% [markdown]
# With this picture in mind, many familiar array-like observations can be done on the ``DataFrame`` itself.
# For example, we can transpose the full ``DataFrame`` to swap rows and columns:

# %%
data.T #transpose
# Out:
#               0          1
# City       Alex      Mecca
# Pop      655500     254400
# Area       2500       9820
# Density   262.2  25.906314
# zip           3          5

# %% [markdown]
# When it comes to indexing of ``DataFrame`` objects, however, it is clear that the dictionary-style indexing of columns precludes our ability to simply treat it as a NumPy array.
# In particular, passing a single index to an array accesses a row:

# %%
data
# Out:
#     City     Pop  Area     Density  zip
# 0   Alex  655500  2500  262.200000    3
# 1  Mecca  254400  9820   25.906314    5

# %% [markdown]
# and passing a single "index" to a ``DataFrame`` accesses a column:

# %%
data['Area']
# Out:
# 0    2500
# 1    9820
# Name: Area, dtype: int64

# %% [markdown]
# **Task**
#
# Create Dataframe with 5 rows with 3 columns
#
# - first column names of students
#
# - second column is age of them
#
# - GPA
#
# what to do ?
#
#     1- create new column with multiply age by 2.36
#
# **Bonus Search**
#
#     2- make column name is index
#     3- call any student by his name to print rest of data

# %%
row1={'name':'karim','age':20,'gpa':3.5}
row2={'name':'ahmed','age':21,'gpa':4}
row3={'name':'amro','age':18,'gpa':4.5}
row4={'name':'hassan','age':17,'gpa':3}
row5={'name':'ali','age':25,'gpa':4.5}

# %%
data = pd.DataFrame([row1, row2,row3,row4,row5])
data
# Out:
#      name  age  gpa
# 0   karim   20  3.5
# 1   ahmed   21  4.0
# 2    amro   18  4.5
# 3  hassan   17  3.0
# 4     ali   25  4.5

# %%
data['age5'] = data['age'] * 2.36

# %%
data
# Out:
#      name  age  gpa   age5
# 0   karim   20  3.5  47.20
# 1   ahmed   21  4.0  49.56
# 2    amro   18  4.5  42.48
# 3  hassan   17  3.0  40.12
# 4     ali   25  4.5  59.00

# %%
data.set_index('name',inplace=True)

# %%
data['karim':'karim']
# Out:
#        age  gpa  age5
# name
# karim   20  3.5  47.2

# %%
data
# Out:
#         age  gpa   age5
# name
# karim    20  3.5  47.20
# ahmed    21  4.0  49.56
# amro     18  4.5  42.48
# hassan   17  3.0  40.12
# ali      25  4.5  59.00

# %%
data.loc['karim']
# Out:
# age      20.0
# gpa       3.5
# age5    100.0
# Name: karim, dtype: float64

# %%
# data[data.index == 'karim']

# %% [markdown]
# ## Loc and iloc

# %% [markdown]
# Because of this potential confusion in the case of integer indexes, Pandas provides some special *indexer* attributes that explicitly expose certain indexing schemes.
# These are not functional methods, but attributes that expose a particular slicing interface to the data in the ``Series``.
#
# First, the ``loc`` attribute allows indexing and slicing that always references the explicit index:

# %%
import pandas as pd

# %%
row_1 = {'City': 'Alex', 'Pop': 655500 , 'Area' : 2500}    # Column name and value
row_2 = {'City': 'Mecca', 'Pop': 254400 , 'Area' : 9820}    # Column name and value


data = pd.DataFrame([row_1, row_2],index=[1,2])
data
# Out:
#     City     Pop  Area
# 1   Alex  655500  2500
# 2  Mecca  254400  9820

# %% [markdown]
# iloc  >  computer eye    # index location   integer location
#
# loc   >  human eye

# %%
data.loc[2]
# Out:
# City     Mecca
# Pop     254400
# Area      9820
# Name: 2, dtype: object

# %%
data.loc[2,'City']   # row , col
# Out:
# 'Mecca'

# %%
data.iloc[1,0]
# Out:
# 'Mecca'

# %%
data
# Out:
#     City     Pop  Area
# 1   Alex  655500  2500
# 2  Mecca  254400  9820

# %%
data.loc[2]
# Out:
# City     Mecca
# Pop     254400
# Area      9820
# Name: 2, dtype: object

# %%
data.iloc[1]
# Out:
# City     Mecca
# Pop     254400
# Area      9820
# Name: 2, dtype: object

# %%
data
# Out:
#     City     Pop  Area
# 1   Alex  655500  2500
# 2  Mecca  254400  9820

# %%
data.loc[1:5]  # loc  human eye
# Out:
#     City     Pop  Area
# 1   Alex  655500  2500
# 2  Mecca  254400  9820

# %%
data.iloc[1:5] # iloc  computer eye
# Out:
#     City     Pop  Area
# 2  Mecca  254400  9820

# %%
data
# Out:
#     City     Pop  Area
# 1   Alex  655500  2500
# 2  Mecca  254400  9820

# %%
print(data.loc[2,'City'])
data.iloc[1,0]
# Out:
# Mecca
# 'Mecca'

# %% [markdown]
# The ``iloc`` attribute allows indexing and slicing that always references the implicit Python-style index:

# %%
data
# Out:
#     City     Pop  Area
# 1   Alex  655500  2500
# 2  Mecca  254400  9820

# %%
data.iloc[2:]
# Out:
# Empty DataFrame
# Columns: [City, Pop, Area]
# Index: []

# %%
data
# Out:
#     City     Pop  Area
# 1   Alex  655500  2500
# 2  Mecca  254400  9820

# %%
data.loc[2]   # take real index from my eyes
# Out:
# City     Mecca
# Pop     254400
# Area      9820
# Name: 2, dtype: object

# %%
data.iloc[0:5] # take index from computer eyes
# Out:
#     City     Pop  Area
# 1   Alex  655500  2500
# 2  Mecca  254400  9820

# %% [markdown]
# Task
#
# 1- create dataframe 3 rows 2 columns with index  1 2 4
#
# 2- print 3rd row using two ways

# %%
# data = pd.DataFrame([row_1, row_2],
#                     index=[2,5])
data
# Out:
#     City     Pop  Area
# 2   Alex  655500  2500
# 5  Mecca  254400  9820

# %%
data.loc[4]

data.iloc[2]

# %% [markdown]
# A third indexing attribute, ``ix``, is a hybrid of the two, and for ``Series`` objects is equivalent to standard ``[]``-based indexing.
# The purpose of the ``ix`` indexer will become more apparent in the context of ``DataFrame`` objects, which we will discuss in a moment.
#
# One guiding principle of Python code is that "explicit is better than implicit."
# The explicit nature of ``loc`` and ``iloc`` make them very useful in maintaining clean and readable code; especially in the case of integer indexes, I recommend using these both to make code easier to read and understand, and to prevent subtle bugs due to the mixed indexing/slicing convention.

# %%
data
# Out:
#     City     Pop  Area
# 2   Alex  655500  2500
# 5  Mecca  254400  9820

# %%
data.iloc[1]
# Out:
# City     Mecca
# Pop     254400
# Area      9820
# Name: 5, dtype: object

# %%
data.loc[6]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 6
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 data.loc[6]
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\generic.py:4095, in NDFrame.xs(self, key, axis, level, drop_level)
#    4093             new_index = index[loc]
#    4094 else:
# -> 4095     loc = index.get_loc(key)
#    4097     if isinstance(loc, np.ndarray):
#    4098         if loc.dtype == np.bool_:
#
# File c:\Users\Legion\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 6

# %% [markdown]
# Thus for array-style indexing, we need another convention.
# Here Pandas again uses the ``loc``, ``iloc``, and ``ix`` indexers mentioned earlier.
# Using the ``iloc`` indexer, we can index the underlying array as if it is a simple NumPy array (using the implicit Python-style index), but the ``DataFrame`` index and column labels are maintained in the result:

# %%
row_1 = {'City': 'Alex', 'Pop': 655500 , 'Area' : 2500}    # Column name and value
row_2 = {'City': 'Mecca', 'Pop': 254400 , 'Area' : 9820}    # Column name and value
row_3 = {'City': 'Cairo', 'Pop': 698500 , 'Area' : 3251}    # Column name and value
row_4 = {'City': 'Giza', 'Pop': 156500 , 'Area' : 1235}    # Column name and value


data = pd.DataFrame([row_1, row_2,row_3, row_4],index=[1,2,4,5])
data
# Out:
#     City     Pop  Area
# 1   Alex  655500  2500
# 2  Mecca  254400  9820
# 4  Cairo  698500  3251
# 5   Giza  156500  1235

# %%
data.iloc[ 1:3 , 1:3 ]  # row  ,  cols
# Out:
#       Pop  Area
# 2  254400  9820
# 4  698500  3251

# %%
data.loc[ 2:4 , 'City':'Pop' ]  #  :  colon   # last element in loc is inclusive
# Out:
#     City     Pop
# 2  Mecca  254400
# 4  Cairo  698500

# %%
data
# Out:
#    Area   City     Pop
# 1  2500   Alex  655500
# 2  9820  Mecca  254400
# 4  3251  Cairo  698500
# 5  1235   Giza  156500

# %%
data.iloc[1:4 , :2]
# Out:
#    Area   City
# 2  9820  Mecca
# 4  3251  Cairo
# 5  1235   Giza

# %%
data
# Out:
#    Area   City     Pop
# 1  2500   Alex  655500
# 2  9820  Mecca  254400
# 4  3251  Cairo  698500
# 5  1235   Giza  156500

# %%
data.iloc[:3, :2]
# Out:
#    Area   City
# 1  2500   Alex
# 2  9820  Mecca
# 4  3251  Cairo

# %% [markdown]
# Similarly, using the ``loc`` indexer we can index the underlying data in an array-like style but using the explicit index and column names:

# %%
data
# Out:
#     City     Pop  Area
# 1   Alex  655500  2500
# 2  Mecca  254400  9820
# 4  Cairo  698500  3251
# 5   Giza  156500  1235

# %%
data.loc[ :1 ,  :'Pop'  ]  # rows   , col    # loc  take real name  last is inclusive
# Out:
#    City     Pop
# 1  Alex  655500

# %%
data
# Out:
#     City     Pop  Area
# 1   Alex  655500  2500
# 2  Mecca  254400  9820
# 4  Cairo  698500  3251
# 5   Giza  156500  1235

# %%
data.loc[ 1 , 'Pop':'Area']
# Out:
# Pop     655500
# Area      2500
# Name: 1, dtype: object

# %%
data.loc[ 1:1 , 'Area':'Pop']
# Out:
# Empty DataFrame
# Columns: []
# Index: [1]

# %% [markdown]
# Any of the familiar NumPy-style data access patterns can be used within these indexers.
# For example, in the ``loc`` indexer we can combine masking and fancy indexing as in the following:
